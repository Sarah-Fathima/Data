# %%
# !pip install -q kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-61739c1a-3f42-4b70-bc06-92cc57ccf4cb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61739c1a-3f42-4b70-bc06-92cc57ccf4cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"sarahfathimaa","key":"8f60934c957d565a6631b1fdda5fc678"}'}

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
 # !kaggle datasets download -d salmaneunus/ttl-fb
# Out:
# ...
#   0% 0.00/64.8k [00:00<?, ?B/s]
# 100% 64.8k/64.8k [00:00<00:00, 25.9MB/s]

# %%
# !unzip ttl-fb.zip
# Out:
# Archive:  ttl-fb.zip
#   inflating: TTL_PAGE.csv
#   inflating: social media visitors.csv
#   inflating: social_media.csv

# %%
import pandas as pd

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              237KB  2021-11-10 18:11:20          15560
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-04-28 17:03:01           9454
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19           4235
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   2GB  2021-10-22 10:48:21           3454
# ...

# %%
report= pd.read_csv('social_media.csv')

report
# Out:
#     Unnamed: 0  ...                                Total_Monthly_Reach
# 0            0  ...  28 Days: The number of people who had any cont...
# 1            2  ...                                               5962
# 2            3  ...                                               6165
# 3            4  ...                                               5991
# 4            5  ...                                               6547
# 5            6  ...                                               6336
# 6            7  ...                                               6173
# 7            8  ...                                               6095
# 8            9  ...                                               6004
# 9           10  ...                                               6045
# 10          11  ...                                               6046
# 11          12  ...                                               6069
# ...

# %%
report['Total_Monthly_Reach'].value_counts()
# Out:
# 3834                                                                                                                                                                                                                                2
# 6045                                                                                                                                                                                                                                2
# 6336                                                                                                                                                                                                                                1
# 6046                                                                                                                                                                                                                                1
# ...

# %%
report.isnull().sum()
# Out:
# Unnamed: 0                   0
# Date                         1
# Daily_Engaged_Users          0
# Monthly_Engaged_Users        0
# Weekly Page Engaged Users    0
# Lifetime Total Likes         0
# Daily Total Reach            0
# Weekly Total Reach           0
# Total_Monthly_Reach          0
# dtype: int64

# %%
report.drop(0,inplace=True)
report
# Out:
#     Unnamed: 0        Date  ... Weekly Total Reach Total_Monthly_Reach
# 1            2  2020-05-01  ...               1112                5962
# 2            3  2020-05-02  ...               1320                6165
# 3            4  2020-05-03  ...               1349                5991
# 4            5  2020-05-04  ...               1820                6547
# 5            6  2020-05-05  ...               1877                6336
# 6            7  2020-05-06  ...               1902                6173
# 7            8  2020-05-07  ...               1917                6095
# 8            9  2020-05-08  ...               1905                6004
# 9           10  2020-05-09  ...               1688                6045
# 10          11  2020-05-10  ...               1628                6046
# 11          12  2020-05-11  ...                689                6069
# 12          13  2020-05-12  ...                516                6058
# ...

# %%
report.drop(columns=['Unnamed: 0'],inplace=True)

# %%
report
# Out:
#           Date Daily_Engaged_Users  ... Weekly Total Reach Total_Monthly_Reach
# 1   2020-05-01                   1  ...               1112                5962
# 2   2020-05-02                  32  ...               1320                6165
# 3   2020-05-03                  29  ...               1349                5991
# 4   2020-05-04                 117  ...               1820                6547
# 5   2020-05-05                  17  ...               1877                6336
# 6   2020-05-06                   6  ...               1902                6173
# 7   2020-05-07                  10  ...               1917                6095
# 8   2020-05-08                   3  ...               1905                6004
# 9   2020-05-09                   3  ...               1688                6045
# 10  2020-05-10                   2  ...               1628                6046
# 11  2020-05-11                   2  ...                689                6069
# ...

# %%
report['Date'].min()
# Out:
# '2020-05-01'

# %%
report['Date'].max()
# Out:
# '2020-05-29'

# %%
report.reset_index(inplace=True)
report
# Out:
#     index        Date  ... Weekly Total Reach Total_Monthly_Reach
# 0       1  2020-05-01  ...               1112                5962
# 1       2  2020-05-02  ...               1320                6165
# 2       3  2020-05-03  ...               1349                5991
# 3       4  2020-05-04  ...               1820                6547
# 4       5  2020-05-05  ...               1877                6336
# 5       6  2020-05-06  ...               1902                6173
# 6       7  2020-05-07  ...               1917                6095
# 7       8  2020-05-08  ...               1905                6004
# 8       9  2020-05-09  ...               1688                6045
# 9      10  2020-05-10  ...               1628                6046
# 10     11  2020-05-11  ...                689                6069
# 11     12  2020-05-12  ...                516                6058
# 12     13  2020-05-13  ...                445                6045
# ...

# %%
report.set_index('Date',inplace =True)
report
# Out:
#             index Daily_Engaged_Users  ... Weekly Total Reach Total_Monthly_Reach
# Date                                   ...
# 2020-05-01      1                   1  ...               1112                5962
# 2020-05-02      2                  32  ...               1320                6165
# 2020-05-03      3                  29  ...               1349                5991
# 2020-05-04      4                 117  ...               1820                6547
# 2020-05-05      5                  17  ...               1877                6336
# 2020-05-06      6                   6  ...               1902                6173
# 2020-05-07      7                  10  ...               1917                6095
# 2020-05-08      8                   3  ...               1905                6004
# 2020-05-09      9                   3  ...               1688                6045
# 2020-05-10     10                   2  ...               1628                6046
# ...

# %%
report.head()
# Out:
#             index Daily_Engaged_Users  ... Weekly Total Reach Total_Monthly_Reach
# Date                                   ...
# 2020-05-01      1                   1  ...               1112                5962
# 2020-05-02      2                  32  ...               1320                6165
# 2020-05-03      3                  29  ...               1349                5991
# 2020-05-04      4                 117  ...               1820                6547
# 2020-05-05      5                  17  ...               1877                6336
#
# [5 rows x 8 columns]

# %%
report.head()
# Out:
#             index Daily_Engaged_Users  ... Weekly Total Reach Total_Monthly_Reach
# Date                                   ...
# 2020-05-01      1                   1  ...               1112                5962
# 2020-05-02      2                  32  ...               1320                6165
# 2020-05-03      3                  29  ...               1349                5991
# 2020-05-04      4                 117  ...               1820                6547
# 2020-05-05      5                  17  ...               1877                6336
#
# [5 rows x 8 columns]

# %%
report.tail(10)
# Out:
#             index Daily_Engaged_Users  ... Weekly Total Reach Total_Monthly_Reach
# Date                                   ...
# 2020-05-20     20                  18  ...                843                3648
# 2020-05-21     21                  12  ...                849                3612
# 2020-05-22     22                   7  ...                867                3434
# 2020-05-23     23                  44  ...               1245                3660
# 2020-05-24     24                  11  ...               1394                3770
# 2020-05-25     25                  43  ...               1623                3834
# 2020-05-26     26                  18  ...               1679                3834
# 2020-05-27     27                  14  ...               1684                3867
# 2020-05-28     28                   2  ...               1737                3887
# 2020-05-29     29                   4  ...               1714                3893
#
# [10 rows x 8 columns]

# %%
report.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29 entries, 2020-05-01 to 2020-05-29
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      29 non-null     int64
#  1   Daily_Engaged_Users        29 non-null     object
#  2   Monthly_Engaged_Users      29 non-null     object
#  3   Weekly Page Engaged Users  29 non-null     object
#  4   Lifetime Total Likes       29 non-null     object
#  5   Daily Total Reach          29 non-null     object
#  6   Weekly Total Reach         29 non-null     object
#  7   Total_Monthly_Reach        29 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 2.0+ KB

# %%
report.shape
# Out:
# (29, 8)

# %%
report.count()
# Out:
# index                        29
# Daily_Engaged_Users          29
# Monthly_Engaged_Users        29
# Weekly Page Engaged Users    29
# Lifetime Total Likes         29
# Daily Total Reach            29
# Weekly Total Reach           29
# Total_Monthly_Reach          29
# dtype: int64

# %%
report.median()
# Out:
# index                           15.0
# Daily_Engaged_Users              7.0
# Monthly_Engaged_Users          645.0
# Weekly Page Engaged Users      104.0
# Lifetime Total Likes         11023.0
# Daily Total Reach               97.0
# Weekly Total Reach            1320.0
# Total_Monthly_Reach           5962.0
# dtype: float64

# %%
report.mean()
# Out:
# index                         1.500000e+01
# Daily_Engaged_Users           4.561765e+40
# Monthly_Engaged_Users         2.889141e+85
# Weekly Page Engaged Users     2.831073e+72
# Lifetime Total Likes         3.800383e+142
# Daily Total Reach             2.016908e+70
# Weekly Total Reach           3.834938e+101
# Total_Monthly_Reach          2.056075e+114
# dtype: float64

# %%
report.rename(columns={'Weekly Page Engaged Users' : 'page'},inplace=True)
report
# Out:
#             index Daily_Engaged_Users  ... Weekly Total Reach Total_Monthly_Reach
# Date                                   ...
# 2020-05-01      1                   1  ...               1112                5962
# 2020-05-02      2                  32  ...               1320                6165
# 2020-05-03      3                  29  ...               1349                5991
# 2020-05-04      4                 117  ...               1820                6547
# 2020-05-05      5                  17  ...               1877                6336
# 2020-05-06      6                   6  ...               1902                6173
# 2020-05-07      7                  10  ...               1917                6095
# 2020-05-08      8                   3  ...               1905                6004
# 2020-05-09      9                   3  ...               1688                6045
# 2020-05-10     10                   2  ...               1628                6046
# ...

# %%
report.astype(object)
report.describe()
# Out:
#            index
# count  29.000000
# mean   15.000000
# std     8.514693
# min     1.000000
# 25%     8.000000
# 50%    15.000000
# 75%    22.000000
# max    29.000000
